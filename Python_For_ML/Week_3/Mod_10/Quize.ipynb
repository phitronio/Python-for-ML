# %%
import numpy as np

arr = np.array([1,2,3])
print(arr.ndim)
# Out:
# 1

# %%
arr = np.array([1, 2.5, 3])
print(arr.dtype)
# Out:
# float64

# %%
np.linspace(0,10,5)
# Out:
# array([ 0. ,  2.5,  5. ,  7.5, 10. ])

# %%
arr2 = np.full((2,2), np.inf)
print(arr2)
# Out:
# [[inf inf]
#  [inf inf]]

# %%
arr3 = np.array([[10,20,30],[40,50,60]])
print(arr3[:,1])
# Out:
# [20 50]

# %%
import numpy as np
arr = np.random.rand(2, 3)
print(arr)
# Out:
# [[0.38123901 0.47303471 0.79894741]
#  [0.76994739 0.24178974 0.77724551]]

# %%
arr5 = np.array([1,2,3,4,5])
arr5[1:4] = 0
print(arr5)
# Out:
# [1 0 0 0 5]
