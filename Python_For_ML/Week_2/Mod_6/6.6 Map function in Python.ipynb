# %%
lst = [1,2,3,4,5]

def sq(x):
    return x**2
lst = map(sq,lst)
print(lst)

# %%
lst = [1,2,3,4,5]

def sq(x):
    return x**2
lst = list(map(sq,lst))
print(lst)
# Out:
# [1, 4, 9, 16, 25]

# %%
string = "abcd efgh "
string1 = list(map(str.upper,string))
print(string1)

string1= " ".join(string1)
print(string1)
# Out:
# ['A', 'B', 'C', 'D', ' ', 'E', 'F', 'G', 'H', ' ']
# A B C D   E F G H

# %%
lst = [1,2,3,4,5,6]
lst = list(map(lambda x : x**2, lst))

print(lst)
